# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull().sum() #perfect data with no null values
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.shape
# Out:
# (150, 6)

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df['SepalLengthCm'].mean()
# Out:
# 5.843333333333334

# %%
df['Species'].max()
# Out:
# 'Iris-virginica'

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
by_species=df.groupby('Species').mean()
by_species.drop('Id',axis=1,inplace=True)

# %%
by_species
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         3.418          1.464         0.244
# Iris-versicolor          5.936         2.770          4.260         1.326
# Iris-virginica           6.588         2.974          5.552         2.026

# %%
by_species1=df.groupby('Species').std()
by_species1.drop('Id',axis=1,inplace=True)
by_species1
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa           0.352490      0.381024       0.173511      0.107210
# Iris-versicolor       0.516171      0.313798       0.469911      0.197753
# Iris-virginica        0.635880      0.322497       0.551895      0.274650

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop('Id',axis=1,inplace=True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.displot(df['PetalLengthCm'])

# %%
sns.jointplot(x='PetalLengthCm',y='PetalWidthCm',data=df,kind='scatter')

# %%
sns.jointplot(x='PetalLengthCm',y='PetalWidthCm',data=df,kind='hex')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Species')

# %%
sns.barplot(x='Species',y='SepalWidthCm',data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.boxplot(x="Species", y="PetalLengthCm", data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
from pandas.plotting import radviz
import matplotlib.pyplot as plt

# Assuming iris is your DataFrame
# Drop the "Id" column only if it exists
if "Id" in df.columns:
    df = df.drop("Id", axis=1)

radviz(df, "Species", colormap='autumn')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Iris.csv')
# Assuming df is your DataFrame containing the data
plt.figure(figsize=(8, 6))
plt.title('Comparing different species based on their sepal length and width')
sns.scatterplot(df['SepalLengthCm'], df['SepalWidthCm'], hue=df['Species'], s=50)
plt.show()
# Out:
# C:\python3102\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,6))

plt.title('Comparing different species based on their petal length and petal width')

sns.scatterplot(df['PetalLengthCm'], df['PetalWidthCm'], hue = df['Species'], s= 50)
# Out:
# C:\python3102\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Comparing different species based on their petal length and petal width'}, xlabel='PetalLengthCm', ylabel='PetalWidthCm'>
